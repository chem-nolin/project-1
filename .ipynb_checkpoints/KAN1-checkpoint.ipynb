# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import json
import os

results_json = os.path.join("urpublications.json")

# %%
pprint(results_json)
# Out:
# 'urpublications.json'
