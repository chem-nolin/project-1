# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import json
import os

# %%
with open("urpublications.json") as f:
    data=json.load(f)
    
pprint(data)
# Out:
# {'message': {'facets': {},
#              'items': [{'DOI': '10.1002/cm.21305',
#                         'ISSN': ['1949-3584'],
#                         'URL': 'http://dx.doi.org/10.1002/cm.21305',
#                         'archive': ['Portico'],
#                         'author': [{'affiliation': [{'name': 'Department of '
#                                                              'Biology; '
#                                                              'University of '
#                                                              'Richmond; '
#                                                              'Richmond '
#                                                              'Virginia'}],
#                                     'family': 'Hawthorne',
#                                     'given': 'Jenci L.',
#                                     'sequence': 'first'},
#                                    {'affiliation': [{'name': 'Department of '
# ...
